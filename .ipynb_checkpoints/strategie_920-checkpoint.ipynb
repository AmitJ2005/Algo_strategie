# %%
import requests as rq
import pandas as pd
import datetime as dt
from time import sleep
import os
from dotenv import load_dotenv

load_dotenv()
access_token = os.getenv('ACCESS_TOKEN')

# %%
# Data downlaod kiya for get option chain data

df = pd.read_csv("https://assets.upstox.com/market-quote/instruments/exchange/complete.csv.gz")
df
# Out:
#                     instrument_key  exchange_token      tradingsymbol  \
# 0               NSE_INDEX|Nifty 50            17.0                NaN
# 1       NSE_INDEX|NIFTY100 EQL Wgt             NaN                NaN
# 2        NSE_INDEX|NIFTY50 EQL Wgt             NaN                NaN
# 3      NSE_INDEX|NiftyM150Momntm50             NaN                NaN
# 4             NSE_INDEX|Nifty Auto            48.0                NaN
# ...                            ...             ...                ...
# 81876               BCD_FO|1081146       1081146.0  USDINR24D1386.4PE
# 81877               BCD_FO|1081147       1081147.0  USDINR24D1386.6CE
# 81878               BCD_FO|1081148       1081148.0  USDINR24D1386.6PE
# 81879               BCD_FO|1081149       1081149.0  USDINR24D1386.7CE
# 81880               BCD_FO|1081150       1081150.0  USDINR24D1386.7PE
#
#                     name  last_price      expiry  strike  tick_size  lot_size  \
# 0               Nifty 50    23518.50         NaN     NaN        NaN       NaN
# 1       NIFTY100 EQL Wgt    31267.10         NaN     NaN        NaN       NaN
# 2        NIFTY50 EQL Wgt    29465.45         NaN     NaN        NaN       NaN
# 3      NiftyM150Momntm50    61755.85         NaN     NaN        NaN       NaN
# 4             Nifty Auto    23359.50         NaN     NaN        NaN       NaN
# ...                  ...         ...         ...     ...        ...       ...
# 81876             USDINR        0.00  2024-12-13    86.4       0.25       1.0
# 81877             USDINR        0.00  2024-12-13    86.6       0.25       1.0
# 81878             USDINR        0.00  2024-12-13    86.6       0.25       1.0
# 81879             USDINR        0.00  2024-12-13    86.7       0.25       1.0
# 81880             USDINR        0.00  2024-12-13    86.7       0.25       1.0
#
#       instrument_type option_type   exchange
# 0               INDEX         NaN  NSE_INDEX
# 1               INDEX         NaN  NSE_INDEX
# 2               INDEX         NaN  NSE_INDEX
# 3               INDEX         NaN  NSE_INDEX
# 4               INDEX         NaN  NSE_INDEX
# ...               ...         ...        ...
# 81876          FUTCUR          FF     BCD_FO
# 81877          FUTCUR          FF     BCD_FO
# 81878          FUTCUR          FF     BCD_FO
# 81879          FUTCUR          FF     BCD_FO
# 81880          FUTCUR          FF     BCD_FO
#
# [81881 rows x 12 columns]

# %%
# function to get banknifty option chain data from main data

def filter_df(df,lot_size):
    df = df[(df['exchange'] == 'NSE_FO') &(df['instrument_type'] == 'OPTIDX') &(df['lot_size'] == lot_size)]
    df = df[df['expiry'] ==  min(df['expiry'].unique())]
    return df
BNDF = filter_df(df,15)
BNDF
# Out:
#       instrument_key  exchange_token          tradingsymbol name  last_price  \
# 9375    NSE_FO|38526         38526.0  BANKNIFTY24NOV42500CE  NaN     8475.00
# 9377    NSE_FO|38529         38529.0  BANKNIFTY24NOV42500PE  NaN        1.60
# 9390    NSE_FO|38597         38597.0  BANKNIFTY24NOV43000CE  NaN     7541.65
# 9395    NSE_FO|38675         38675.0  BANKNIFTY24NOV43000PE  NaN        1.85
# 9404    NSE_FO|38747         38747.0  BANKNIFTY24NOV43500CE  NaN     8220.00
# ...              ...             ...                    ...  ...         ...
# 12200   NSE_FO|55605         55605.0  BANKNIFTY24NOV61000PE  NaN    10180.00
# 12201   NSE_FO|55606         55606.0  BANKNIFTY24NOV61500CE  NaN        2.75
# 12202   NSE_FO|55607         55607.0  BANKNIFTY24NOV61500PE  NaN     8696.85
# 12203   NSE_FO|55608         55608.0  BANKNIFTY24NOV62000CE  NaN        2.55
# 12204   NSE_FO|55609         55609.0  BANKNIFTY24NOV62000PE  NaN    11900.00
#
#            expiry   strike  tick_size  lot_size instrument_type option_type  \
# 9375   2024-11-27  42500.0       0.05      15.0          OPTIDX          CE
# 9377   2024-11-27  42500.0       0.05      15.0          OPTIDX          PE
# 9390   2024-11-27  43000.0       0.05      15.0          OPTIDX          CE
# 9395   2024-11-27  43000.0       0.05      15.0          OPTIDX          PE
# 9404   2024-11-27  43500.0       0.05      15.0          OPTIDX          CE
# ...           ...      ...        ...       ...             ...         ...
# 12200  2024-11-27  61000.0       0.05      15.0          OPTIDX          PE
# 12201  2024-11-27  61500.0       0.05      15.0          OPTIDX          CE
# 12202  2024-11-27  61500.0       0.05      15.0          OPTIDX          PE
# 12203  2024-11-27  62000.0       0.05      15.0          OPTIDX          CE
# 12204  2024-11-27  62000.0       0.05      15.0          OPTIDX          PE
#
#       exchange
# 9375    NSE_FO
# 9377    NSE_FO
# 9390    NSE_FO
# 9395    NSE_FO
# 9404    NSE_FO
# ...        ...
# 12200   NSE_FO
# 12201   NSE_FO
# 12202   NSE_FO
# 12203   NSE_FO
# 12204   NSE_FO
#
# [248 rows x 12 columns]

# %%
BNDF[BNDF['option_type'] == 'CE']
# Out:
#       instrument_key  exchange_token          tradingsymbol name  last_price  \
# 9407    NSE_FO|38526         38526.0  BANKNIFTY24NOV42500CE  NaN     9457.60
# 9422    NSE_FO|38597         38597.0  BANKNIFTY24NOV43000CE  NaN     7380.00
# 9436    NSE_FO|38747         38747.0  BANKNIFTY24NOV43500CE  NaN     8220.00
# 9450    NSE_FO|38915         38915.0  BANKNIFTY24NOV44000CE  NaN     6250.00
# 9454    NSE_FO|38963         38963.0  BANKNIFTY24NOV44500CE  NaN     7592.70
# ...              ...             ...                    ...  ...         ...
# 12059   NSE_FO|55598         55598.0  BANKNIFTY24NOV60000CE  NaN        4.15
# 12061   NSE_FO|55602         55602.0  BANKNIFTY24NOV60500CE  NaN        3.85
# 12063   NSE_FO|55604         55604.0  BANKNIFTY24NOV61000CE  NaN        3.85
# 12065   NSE_FO|55606         55606.0  BANKNIFTY24NOV61500CE  NaN        3.70
# 12067   NSE_FO|55608         55608.0  BANKNIFTY24NOV62000CE  NaN        3.65
#
#            expiry   strike  tick_size  lot_size instrument_type option_type  \
# 9407   2024-11-27  42500.0       0.05      15.0          OPTIDX          CE
# 9422   2024-11-27  43000.0       0.05      15.0          OPTIDX          CE
# 9436   2024-11-27  43500.0       0.05      15.0          OPTIDX          CE
# 9450   2024-11-27  44000.0       0.05      15.0          OPTIDX          CE
# 9454   2024-11-27  44500.0       0.05      15.0          OPTIDX          CE
# ...           ...      ...        ...       ...             ...         ...
# 12059  2024-11-27  60000.0       0.05      15.0          OPTIDX          CE
# 12061  2024-11-27  60500.0       0.05      15.0          OPTIDX          CE
# 12063  2024-11-27  61000.0       0.05      15.0          OPTIDX          CE
# 12065  2024-11-27  61500.0       0.05      15.0          OPTIDX          CE
# 12067  2024-11-27  62000.0       0.05      15.0          OPTIDX          CE
#
#       exchange
# 9407    NSE_FO
# 9422    NSE_FO
# 9436    NSE_FO
# 9450    NSE_FO
# 9454    NSE_FO
# ...        ...
# 12059   NSE_FO
# 12061   NSE_FO
# 12063   NSE_FO
# 12065   NSE_FO
# 12067   NSE_FO
#
# [124 rows x 12 columns]

# %%
optionChain = list(BNDF['instrument_key'])
optionChain
# Out:
# ['NSE_FO|38526',
#  'NSE_FO|38529',
#  'NSE_FO|38597',
#  'NSE_FO|38675',
#  'NSE_FO|38747',
#  'NSE_FO|38805',
#  'NSE_FO|38915',
#  'NSE_FO|38916',
#  'NSE_FO|38963',
#  'NSE_FO|38964',
#  'NSE_FO|39040',
#  'NSE_FO|39041',
#  'NSE_FO|39111',
#  'NSE_FO|39122',
#  'NSE_FO|39174',
#  'NSE_FO|39175',
#  'NSE_FO|39186',
#  'NSE_FO|39187',
#  'NSE_FO|39198',
#  'NSE_FO|39199',
#  'NSE_FO|39200',
#  'NSE_FO|39201',
#  'NSE_FO|39203',
#  'NSE_FO|39207',
#  'NSE_FO|39208',
#  'NSE_FO|39209',
#  'NSE_FO|39213',
#  'NSE_FO|39215',
#  'NSE_FO|39216',
#  'NSE_FO|39217',
#  'NSE_FO|39218',
#  'NSE_FO|39219',
#  'NSE_FO|39220',
#  'NSE_FO|39221',
#  'NSE_FO|39367',
#  'NSE_FO|39694',
#  'NSE_FO|39695',
#  'NSE_FO|39696',
#  'NSE_FO|39697',
#  'NSE_FO|39698',
#  'NSE_FO|39699',
#  'NSE_FO|40472',
#  'NSE_FO|40473',
#  'NSE_FO|40474',
#  'NSE_FO|40475',
#  'NSE_FO|40476',
#  'NSE_FO|40479',
#  'NSE_FO|40480',
#  'NSE_FO|40484',
#  'NSE_FO|40861',
#  'NSE_FO|40862',
#  'NSE_FO|40875',
#  'NSE_FO|40876',
#  'NSE_FO|40881',
#  'NSE_FO|40884',
#  'NSE_FO|40885',
#  'NSE_FO|40890',
#  'NSE_FO|40927',
#  'NSE_FO|40930',
#  'NSE_FO|40933',
#  'NSE_FO|40937',
#  'NSE_FO|40978',
#  'NSE_FO|40979',
#  'NSE_FO|40999',
#  'NSE_FO|41004',
#  'NSE_FO|41130',
#  'NSE_FO|41132',
#  'NSE_FO|41284',
#  'NSE_FO|41287',
#  'NSE_FO|41288',
#  'NSE_FO|41289',
#  'NSE_FO|41300',
#  'NSE_FO|41301',
#  'NSE_FO|41302',
#  'NSE_FO|41303',
#  'NSE_FO|41305',
#  'NSE_FO|41310',
#  'NSE_FO|41311',
#  'NSE_FO|41312',
#  'NSE_FO|41315',
#  'NSE_FO|41316',
#  'NSE_FO|41317',
#  'NSE_FO|41318',
#  'NSE_FO|41321',
#  'NSE_FO|41322',
#  'NSE_FO|41323',
#  'NSE_FO|41324',
#  'NSE_FO|41353',
#  'NSE_FO|41365',
#  'NSE_FO|41366',
#  'NSE_FO|41384',
#  'NSE_FO|41385',
#  'NSE_FO|41407',
#  'NSE_FO|41408',
#  'NSE_FO|41413',
#  'NSE_FO|41424',
#  'NSE_FO|41441',
#  'NSE_FO|41442',
#  'NSE_FO|41451',
#  'NSE_FO|41452',
#  'NSE_FO|41462',
#  'NSE_FO|41463',
#  'NSE_FO|41468',
#  'NSE_FO|41469',
#  'NSE_FO|41493',
#  'NSE_FO|41498',
#  'NSE_FO|41505',
#  'NSE_FO|41506',
#  'NSE_FO|41511',
#  'NSE_FO|41512',
#  'NSE_FO|41513',
#  'NSE_FO|41516',
#  'NSE_FO|41518',
#  'NSE_FO|41523',
#  'NSE_FO|41524',
#  'NSE_FO|41528',
#  'NSE_FO|41545',
#  'NSE_FO|41546',
#  'NSE_FO|41547',
#  'NSE_FO|41548',
#  'NSE_FO|41554',
#  'NSE_FO|41559',
#  'NSE_FO|41567',
#  'NSE_FO|41575',
#  'NSE_FO|41587',
#  'NSE_FO|41595',
#  'NSE_FO|41600',
#  'NSE_FO|41603',
#  'NSE_FO|41604',
#  'NSE_FO|41605',
#  'NSE_FO|41606',
#  'NSE_FO|41607',
#  'NSE_FO|41611',
#  'NSE_FO|41612',
#  'NSE_FO|41626',
#  'NSE_FO|41627',
#  'NSE_FO|41643',
#  'NSE_FO|41656',
#  'NSE_FO|41661',
#  'NSE_FO|41662',
#  'NSE_FO|41669',
#  'NSE_FO|41675',
#  'NSE_FO|41676',
#  'NSE_FO|41696',
#  'NSE_FO|41697',
#  'NSE_FO|41705',
#  'NSE_FO|41726',
#  'NSE_FO|42694',
#  'NSE_FO|43282',
#  'NSE_FO|43283',
#  'NSE_FO|45782',
#  'NSE_FO|45787',
#  'NSE_FO|45792',
#  'NSE_FO|45797',
#  'NSE_FO|45932',
#  'NSE_FO|46322',
#  'NSE_FO|46323',
#  'NSE_FO|46324',
#  'NSE_FO|46325',
#  'NSE_FO|46326',
#  'NSE_FO|46329',
#  'NSE_FO|46641',
#  'NSE_FO|46642',
#  'NSE_FO|46643',
#  'NSE_FO|46644',
#  'NSE_FO|46657',
#  'NSE_FO|46658',
#  'NSE_FO|46663',
#  'NSE_FO|46667',
#  'NSE_FO|47644',
#  'NSE_FO|47645',
#  'NSE_FO|48323',
#  'NSE_FO|48324',
#  'NSE_FO|48329',
#  'NSE_FO|48334',
#  'NSE_FO|48335',
#  'NSE_FO|48339',
#  'NSE_FO|48340',
#  'NSE_FO|48343',
#  'NSE_FO|48344',
#  'NSE_FO|48345',
#  'NSE_FO|48480',
#  'NSE_FO|48481',
#  'NSE_FO|48660',
#  'NSE_FO|48661',
#  'NSE_FO|51068',
#  'NSE_FO|51069',
#  'NSE_FO|51110',
#  'NSE_FO|51111',
#  'NSE_FO|51112',
#  'NSE_FO|51113',
#  'NSE_FO|51114',
#  'NSE_FO|51115',
#  'NSE_FO|51116',
#  'NSE_FO|51117',
#  'NSE_FO|51829',
#  'NSE_FO|51830',
#  'NSE_FO|51831',
#  'NSE_FO|51832',
#  'NSE_FO|51833',
#  'NSE_FO|51834',
#  'NSE_FO|51835',
#  'NSE_FO|51836',
#  'NSE_FO|51837',
#  'NSE_FO|51838',
#  'NSE_FO|51840',
#  'NSE_FO|51841',
#  'NSE_FO|51842',
#  'NSE_FO|51843',
#  'NSE_FO|51844',
#  'NSE_FO|51845',
#  'NSE_FO|51846',
#  'NSE_FO|51847',
#  'NSE_FO|51848',
#  'NSE_FO|51849',
#  'NSE_FO|51851',
#  'NSE_FO|51852',
#  'NSE_FO|51853',
#  'NSE_FO|51854',
#  'NSE_FO|51855',
#  'NSE_FO|51856',
#  'NSE_FO|53838',
#  'NSE_FO|53839',
#  'NSE_FO|53969',
#  'NSE_FO|53971',
#  'NSE_FO|55145',
#  'NSE_FO|55146',
#  'NSE_FO|55147',
#  'NSE_FO|55148',
#  'NSE_FO|55293',
#  'NSE_FO|55312',
#  'NSE_FO|55313',
#  'NSE_FO|55564',
#  'NSE_FO|55565',
#  'NSE_FO|55574',
#  'NSE_FO|55575',
#  'NSE_FO|55588',
#  'NSE_FO|55589',
#  'NSE_FO|55598',
#  'NSE_FO|55599',
#  'NSE_FO|55602',
#  'NSE_FO|55603',
#  'NSE_FO|55604',
#  'NSE_FO|55605',
#  'NSE_FO|55606',
#  'NSE_FO|55607',
#  'NSE_FO|55608',
#  'NSE_FO|55609']

# %%
# for last price data from option chain

def get_quotes(instrument):
	url = 'https://api-v2.upstox.com/market-quote/ltp'
	headers = {
		'accept': 'application/json',
		'Api-Version': '2.0',
		'Authorization': f'Bearer {access_token}'}
	params = {'symbol': instrument,'interval':'1d'}
	res = rq.get(url, headers=headers, params=params).json()
	return res
ltp_data = get_quotes(optionChain)
ltp_data['data']
# Out:
# {'NSE_FO:BANKNIFTY24NOV43000CE': {'last_price': 7430.0,
#   'instrument_token': 'NSE_FO|38597'},
#  'NSE_FO:BANKNIFTY24NOV47300CE': {'last_price': 0.0,
#   'instrument_token': 'NSE_FO|39208'},
#  'NSE_FO:BANKNIFTY24NOV56200CE': {'last_price': 4.75,
#   'instrument_token': 'NSE_FO|51836'},
#  'NSE_FO:BANKNIFTY24NOV46500CE': {'last_price': 5952.9,
#   'instrument_token': 'NSE_FO|39186'},
#  'NSE_FO:BANKNIFTY24NOV53700PE': {'last_price': 2984.2,
#   'instrument_token': 'NSE_FO|45797'},
#  'NSE_FO:BANKNIFTY24NOV55300PE': {'last_price': 3188.1,
#   'instrument_token': 'NSE_FO|51068'},
#  'NSE_FO:BANKNIFTY24NOV54600CE': {'last_price': 4.85,
#   'instrument_token': 'NSE_FO|47645'},
#  'NSE_FO:BANKNIFTY24NOV51100CE': {'last_price': 223.0,
#   'instrument_token': 'NSE_FO|41462'},
#  'NSE_FO:BANKNIFTY24NOV50300CE': {'last_price': 579.0,
#   'instrument_token': 'NSE_FO|41322'},
#  'NSE_FO:BANKNIFTY24NOV50200PE': {'last_price': 364.3,
#   'instrument_token': 'NSE_FO|41321'},
#  'NSE_FO:BANKNIFTY24NOV55400CE': {'last_price': 5.45,
#   'instrument_token': 'NSE_FO|51069'},
#  'NSE_FO:BANKNIFTY24NOV54500PE': {'last_price': 4000.0,
#   'instrument_token': 'NSE_FO|47644'},
#  'NSE_FO:BANKNIFTY24NOV49900PE': {'last_price': 263.0,
#   'instrument_token': 'NSE_FO|41311'},
#  'NSE_FO:BANKNIFTY24NOV60000CE': {'last_price': 3.35,
#   'instrument_token': 'NSE_FO|55598'},
#  'NSE_FO:BANKNIFTY24NOV51000PE': {'last_price': 783.8,
#   'instrument_token': 'NSE_FO|41452'},
#  'NSE_FO:BANKNIFTY24NOV52200PE': {'last_price': 1772.05,
#   'instrument_token': 'NSE_FO|41575'},
#  'NSE_FO:BANKNIFTY24NOV42500PE': {'last_price': 1.65,
#   'instrument_token': 'NSE_FO|38529'},
#  'NSE_FO:BANKNIFTY24NOV47200PE': {'last_price': 18.0,
#   'instrument_token': 'NSE_FO|39207'},
#  'NSE_FO:BANKNIFTY24NOV53400CE': {'last_price': 9.6,
#   'instrument_token': 'NSE_FO|41726'},
#  'NSE_FO:BANKNIFTY24NOV56500PE': {'last_price': 5900.0,
#   'instrument_token': 'NSE_FO|51844'},
#  'NSE_FO:BANKNIFTY24NOV51800CE': {'last_price': 82.15,
#   'instrument_token': 'NSE_FO|41524'},
#  'NSE_FO:BANKNIFTY24NOV51700PE': {'last_price': 1330.9,
#   'instrument_token': 'NSE_FO|41523'},
#  'NSE_FO:BANKNIFTY24NOV57000CE': {'last_price': 4.3,
#   'instrument_token': 'NSE_FO|51854'},
#  'NSE_FO:BANKNIFTY24NOV48500CE': {'last_price': 2020.0,
#   'instrument_token': 'NSE_FO|40484'},
#  'NSE_FO:BANKNIFTY24NOV52900PE': {'last_price': 2338.85,
#   'instrument_token': 'NSE_FO|41656'},
#  'NSE_FO:BANKNIFTY24NOV61500CE': {'last_price': 3.0,
#   'instrument_token': 'NSE_FO|55606'},
#  'NSE_FO:BANKNIFTY24NOV48400PE': {'last_price': 52.0,
#   'instrument_token': 'NSE_FO|40480'},
#  'NSE_FO:BANKNIFTY24NOV48700PE': {'last_price': 75.15,
#   'instrument_token': 'NSE_FO|40881'},
#  'NSE_FO:BANKNIFTY24NOV53300PE': {'last_price': 2692.65,
#   'instrument_token': 'NSE_FO|41705'},
#  'NSE_FO:BANKNIFTY24NOV55800CE': {'last_price': 4.15,
#   'instrument_token': 'NSE_FO|51117'},
#  'NSE_FO:BANKNIFTY24NOV47700CE': {'last_price': 2544.1,
#   'instrument_token': 'NSE_FO|39220'},
#  'NSE_FO:BANKNIFTY24NOV51500CE': {'last_price': 129.0,
#   'instrument_token': 'NSE_FO|41511'},
#  'NSE_FO:BANKNIFTY24NOV62000CE': {'last_price': 2.8,
#   'instrument_token': 'NSE_FO|55608'},
#  'NSE_FO:BANKNIFTY24NOV58500PE': {'last_price': 6717.35,
#   'instrument_token': 'NSE_FO|55565'},
#  'NSE_FO:BANKNIFTY24NOV55000PE': {'last_price': 4507.9,
#   'instrument_token': 'NSE_FO|48344'},
#  'NSE_FO:BANKNIFTY24NOV59000CE': {'last_price': 3.4,
#   'instrument_token': 'NSE_FO|55574'},
#  'NSE_FO:BANKNIFTY24NOV50700CE': {'last_price': 368.0,
#   'instrument_token': 'NSE_FO|41407'},
#  'NSE_FO:BANKNIFTY24NOV50600PE': {'last_price': 545.0,
#   'instrument_token': 'NSE_FO|41385'},
#  'NSE_FO:BANKNIFTY24NOV49200CE': {'last_price': 1386.65,
#   'instrument_token': 'NSE_FO|40979'},
#  'NSE_FO:BANKNIFTY24NOV54900PE': {'last_price': 3574.05,
#   'instrument_token': 'NSE_FO|48340'},
#  'NSE_FO:BANKNIFTY24NOV49500PE': {'last_price': 172.0,
#   'instrument_token': 'NSE_FO|41288'},
#  'NSE_FO:BANKNIFTY24NOV49600CE': {'last_price': 1068.55,
#   'instrument_token': 'NSE_FO|41289'},
#  'NSE_FO:BANKNIFTY24NOV47000CE': {'last_price': 3560.25,
#   'instrument_token': 'NSE_FO|39198'},
#  'NSE_FO:BANKNIFTY24NOV44500CE': {'last_price': 0.0,
#   'instrument_token': 'NSE_FO|38963'},
#  'NSE_FO:BANKNIFTY24NOV51400PE': {'last_price': 1068.65,
#   'instrument_token': 'NSE_FO|41506'},
#  'NSE_FO:BANKNIFTY24NOV48000PE': {'last_price': 40.4,
#   'instrument_token': 'NSE_FO|39698'},
#  'NSE_FO:BANKNIFTY24NOV47600PE': {'last_price': 28.5,
#   'instrument_token': 'NSE_FO|39219'},
#  'NSE_FO:BANKNIFTY24NOV48800CE': {'last_price': 1920.0,
#   'instrument_token': 'NSE_FO|40884'},
#  'NSE_FO:BANKNIFTY24NOV55700PE': {'last_price': 3684.85,
#   'instrument_token': 'NSE_FO|51116'},
#  'NSE_FO:BANKNIFTY24NOV56900CE': {'last_price': 4.75,
#   'instrument_token': 'NSE_FO|51852'},
#  'NSE_FO:BANKNIFTY24NOV56100PE': {'last_price': 5104.75,
#   'instrument_token': 'NSE_FO|51835'},
#  'NSE_FO:BANKNIFTY24NOV57300CE': {'last_price': 4.0,
#   'instrument_token': 'NSE_FO|53971'},
#  'NSE_FO:BANKNIFTY24NOV53000CE': {'last_price': 16.0,
#   'instrument_token': 'NSE_FO|41661'},
#  'NSE_FO:BANKNIFTY24NOV57200PE': {'last_price': 0.0,
#   'instrument_token': 'NSE_FO|53969'},
#  'NSE_FO:BANKNIFTY24NOV61000PE': {'last_price': 10180.0,
#   'instrument_token': 'NSE_FO|55605'},
#  'NSE_FO:BANKNIFTY24NOV50000CE': {'last_price': 769.0,
#   'instrument_token': 'NSE_FO|41312'},
#  'NSE_FO:BANKNIFTY24NOV54200PE': {'last_price': 3904.1,
#   'instrument_token': 'NSE_FO|46643'},
#  'NSE_FO:BANKNIFTY24NOV54300CE': {'last_price': 6.45,
#   'instrument_token': 'NSE_FO|46644'},
#  'NSE_FO:BANKNIFTY24NOV52600CE': {'last_price': 28.0,
#   'instrument_token': 'NSE_FO|41606'},
#  'NSE_FO:BANKNIFTY24NOV56800PE': {'last_price': 4026.85,
#   'instrument_token': 'NSE_FO|51851'},
#  'NSE_FO:BANKNIFTY24NOV52500PE': {'last_price': 2064.0,
#   'instrument_token': 'NSE_FO|41605'},
#  'NSE_FO:BANKNIFTY24NOV48100CE': {'last_price': 2171.3,
#   'instrument_token': 'NSE_FO|39699'},
#  'NSE_FO:BANKNIFTY24NOV60000PE': {'last_price': 9459.55,
#   'instrument_token': 'NSE_FO|55599'},
#  'NSE_FO:BANKNIFTY24NOV49100PE': {'last_price': 116.0,
#   'instrument_token': 'NSE_FO|40978'},
#  'NSE_FO:BANKNIFTY24NOV50200CE': {'last_price': 629.95,
#   'instrument_token': 'NSE_FO|41318'},
#  'NSE_FO:BANKNIFTY24NOV54500CE': {'last_price': 5.6,
#   'instrument_token': 'NSE_FO|46667'},
#  'NSE_FO:BANKNIFTY24NOV55400PE': {'last_price': 0.0,
#   'instrument_token': 'NSE_FO|51110'},
#  'NSE_FO:BANKNIFTY24NOV51100PE': {'last_price': 852.5,
#   'instrument_token': 'NSE_FO|41463'},
#  'NSE_FO:BANKNIFTY24NOV48100PE': {'last_price': 42.45,
#   'instrument_token': 'NSE_FO|40472'},
#  'NSE_FO:BANKNIFTY24NOV57100CE': {'last_price': 3.9,
#   'instrument_token': 'NSE_FO|51856'},
#  'NSE_FO:BANKNIFTY24NOV57000PE': {'last_price': 6405.0,
#   'instrument_token': 'NSE_FO|51855'},
#  'NSE_FO:BANKNIFTY24NOV46500PE': {'last_price': 10.2,
#   'instrument_token': 'NSE_FO|39187'},
#  'NSE_FO:BANKNIFTY24NOV53600PE': {'last_price': 3131.25,
#   'instrument_token': 'NSE_FO|45787'},
#  'NSE_FO:BANKNIFTY24NOV53700CE': {'last_price': 8.1,
#   'instrument_token': 'NSE_FO|45792'},
#  'NSE_FO:BANKNIFTY24NOV50100PE': {'last_price': 329.95,
#   'instrument_token': 'NSE_FO|41317'},
#  'NSE_FO:BANKNIFTY24NOV51700CE': {'last_price': 94.0,
#   'instrument_token': 'NSE_FO|41518'},
#  'NSE_FO:BANKNIFTY24NOV50500PE': {'last_price': 489.4,
#   'instrument_token': 'NSE_FO|41366'},
#  'NSE_FO:BANKNIFTY24NOV49700CE': {'last_price': 988.55,
#   'instrument_token': 'NSE_FO|41301'},
#  'NSE_FO:BANKNIFTY24NOV61500PE': {'last_price': 8696.85,
#   'instrument_token': 'NSE_FO|55607'},
#  'NSE_FO:BANKNIFTY24NOV55100CE': {'last_price': 5.35,
#   'instrument_token': 'NSE_FO|48345'},
#  'NSE_FO:BANKNIFTY24NOV54800PE': {'last_price': 4226.75,
#   'instrument_token': 'NSE_FO|48335'},
#  'NSE_FO:BANKNIFTY24NOV48500PE': {'last_price': 61.5,
#   'instrument_token': 'NSE_FO|40861'},
#  'NSE_FO:BANKNIFTY24NOV52100PE': {'last_price': 1668.0,
#   'instrument_token': 'NSE_FO|41559'},
#  'NSE_FO:BANKNIFTY24NOV56500CE': {'last_price': 4.5,
#   'instrument_token': 'NSE_FO|51843'},
#  'NSE_FO:BANKNIFTY24NOV46000CE': {'last_price': 4460.0,
#   'instrument_token': 'NSE_FO|39174'},
#  'NSE_FO:BANKNIFTY24NOV47200CE': {'last_price': 3800.0,
#   'instrument_token': 'NSE_FO|39203'},
#  'NSE_FO:BANKNIFTY24NOV47100PE': {'last_price': 17.05,
#   'instrument_token': 'NSE_FO|39201'},
#  'NSE_FO:BANKNIFTY24NOV52200CE': {'last_price': 48.9,
#   'instrument_token': 'NSE_FO|41567'},
#  'NSE_FO:BANKNIFTY24NOV56400PE': {'last_price': 0.0,
#   'instrument_token': 'NSE_FO|51842'},
#  'NSE_FO:BANKNIFTY24NOV60500PE': {'last_price': 7700.0,
#   'instrument_token': 'NSE_FO|55603'},
#  'NSE_FO:BANKNIFTY24NOV52300CE': {'last_price': 42.85,
#   'instrument_token': 'NSE_FO|41587'},
#  'NSE_FO:BANKNIFTY24NOV56600CE': {'last_price': 4.7,
#   'instrument_token': 'NSE_FO|51845'},
#  'NSE_FO:BANKNIFTY24NOV54000CE': {'last_price': 7.5,
#   'instrument_token': 'NSE_FO|46325'},
#  'NSE_FO:BANKNIFTY24NOV47900PE': {'last_price': 33.95,
#   'instrument_token': 'NSE_FO|39696'},
#  'NSE_FO:BANKNIFTY24NOV49600PE': {'last_price': 194.5,
#   'instrument_token': 'NSE_FO|41300'},
#  'NSE_FO:BANKNIFTY24NOV50600CE': {'last_price': 419.6,
#   'instrument_token': 'NSE_FO|41384'},
#  'NSE_FO:BANKNIFTY24NOV49300CE': {'last_price': 1312.0,
#   'instrument_token': 'NSE_FO|41004'},
#  'NSE_FO:BANKNIFTY24NOV54900CE': {'last_price': 5.7,
#   'instrument_token': 'NSE_FO|48339'},
#  'NSE_FO:BANKNIFTY24NOV47000PE': {'last_price': 17.5,
#   'instrument_token': 'NSE_FO|39199'},
#  'NSE_FO:BANKNIFTY24NOV51500PE': {'last_price': 1151.95,
#   'instrument_token': 'NSE_FO|41512'},
#  'NSE_FO:BANKNIFTY24NOV48700CE': {'last_price': 2359.0,
#   'instrument_token': 'NSE_FO|40876'},
#  'NSE_FO:BANKNIFTY24NOV48600PE': {'last_price': 71.0,
#   'instrument_token': 'NSE_FO|40875'},
#  'NSE_FO:BANKNIFTY24NOV55900CE': {'last_price': 4.85,
#   'instrument_token': 'NSE_FO|51830'},
#  'NSE_FO:BANKNIFTY24NOV50900PE': {'last_price': 711.0,
#   'instrument_token': 'NSE_FO|41442'},
#  'NSE_FO:BANKNIFTY24NOV53200PE': {'last_price': 2650.9,
#   'instrument_token': 'NSE_FO|41696'},
#  'NSE_FO:BANKNIFTY24NOV51600CE': {'last_price': 114.0,
#   'instrument_token': 'NSE_FO|41513'},
#  'NSE_FO:BANKNIFTY24NOV55800PE': {'last_price': 4352.15,
#   'instrument_token': 'NSE_FO|51829'},
#  'NSE_FO:BANKNIFTY24NOV55000CE': {'last_price': 5.3,
#   'instrument_token': 'NSE_FO|48343'},
#  'NSE_FO:BANKNIFTY24NOV46000PE': {'last_price': 9.25,
#   'instrument_token': 'NSE_FO|39175'},
#  'NSE_FO:BANKNIFTY24NOV57500PE': {'last_price': 7129.0,
#   'instrument_token': 'NSE_FO|55293'},
#  'NSE_FO:BANKNIFTY24NOV53300CE': {'last_price': 10.45,
#   'instrument_token': 'NSE_FO|41697'},
#  'NSE_FO:BANKNIFTY24NOV57200CE': {'last_price': 3.8,
#   'instrument_token': 'NSE_FO|53839'},
#  'NSE_FO:BANKNIFTY24NOV51200CE': {'last_price': 195.0,
#   'instrument_token': 'NSE_FO|41468'},
#  'NSE_FO:BANKNIFTY24NOV55500CE': {'last_price': 4.8,
#   'instrument_token': 'NSE_FO|51111'},
#  'NSE_FO:BANKNIFTY24NOV54300PE': {'last_price': 3824.8,
#   'instrument_token': 'NSE_FO|46657'},
#  'NSE_FO:BANKNIFTY24NOV53800CE': {'last_price': 7.5,
#   'instrument_token': 'NSE_FO|45932'},
#  'NSE_FO:BANKNIFTY24NOV50000PE': {'last_price': 296.5,
#   'instrument_token': 'NSE_FO|41315'},
#  'NSE_FO:BANKNIFTY24NOV52600PE': {'last_price': 2144.0,
#   'instrument_token': 'NSE_FO|41607'},
#  'NSE_FO:BANKNIFTY24NOV48200CE': {'last_price': 2321.5,
#   'instrument_token': 'NSE_FO|40473'},
#  'NSE_FO:BANKNIFTY24NOV47500PE': {'last_price': 25.5,
#   'instrument_token': 'NSE_FO|39217'},
#  'NSE_FO:BANKNIFTY24NOV56900PE': {'last_price': 0.0,
#   'instrument_token': 'NSE_FO|51853'},
#  'NSE_FO:BANKNIFTY24NOV52700CE': {'last_price': 24.55,
#   'instrument_token': 'NSE_FO|41611'},
#  'NSE_FO:BANKNIFTY24NOV45000CE': {'last_price': 5500.0,
#   'instrument_token': 'NSE_FO|39040'},
#  'NSE_FO:BANKNIFTY24NOV49200PE': {'last_price': 125.0,
#   'instrument_token': 'NSE_FO|40999'},
#  'NSE_FO:BANKNIFTY24NOV47600CE': {'last_price': 2820.5,
#   'instrument_token': 'NSE_FO|39218'},
#  'NSE_FO:BANKNIFTY24NOV54400CE': {'last_price': 5.3,
#   'instrument_token': 'NSE_FO|46658'},
#  'NSE_FO:BANKNIFTY24NOV56000PE': {'last_price': 5500.0,
#   'instrument_token': 'NSE_FO|51833'},
#  'NSE_FO:BANKNIFTY24NOV56100CE': {'last_price': 4.8,
#   'instrument_token': 'NSE_FO|51834'},
#  'NSE_FO:BANKNIFTY24NOV52800CE': {'last_price': 21.9,
#   'instrument_token': 'NSE_FO|41626'},
#  'NSE_FO:BANKNIFTY24NOV57100PE': {'last_price': 0.0,
#   'instrument_token': 'NSE_FO|53838'},
#  'NSE_FO:BANKNIFTY24NOV47400PE': {'last_price': 22.85,
#   'instrument_token': 'NSE_FO|39215'},
#  'NSE_FO:BANKNIFTY24NOV49000PE': {'last_price': 103.25,
#   'instrument_token': 'NSE_FO|40933'},
#  'NSE_FO:BANKNIFTY24NOV50100CE': {'last_price': 707.45,
#   'instrument_token': 'NSE_FO|41316'},
#  'NSE_FO:BANKNIFTY24NOV52000PE': {'last_price': 1585.0,
#   'instrument_token': 'NSE_FO|41548'},
#  'NSE_FO:BANKNIFTY24NOV53600CE': {'last_price': 9.2,
#   'instrument_token': 'NSE_FO|45782'},
#  'NSE_FO:BANKNIFTY24NOV56300PE': {'last_price': 5066.35,
#   'instrument_token': 'NSE_FO|51840'},
#  'NSE_FO:BANKNIFTY24NOV47100CE': {'last_price': 0.0,
#   'instrument_token': 'NSE_FO|39200'},
#  'NSE_FO:BANKNIFTY24NOV48200PE': {'last_price': 40.0,
#   'instrument_token': 'NSE_FO|40474'},
#  'NSE_FO:BANKNIFTY24NOV48300CE': {'last_price': 1937.1,
#   'instrument_token': 'NSE_FO|40475'},
#  'NSE_FO:BANKNIFTY24NOV44000CE': {'last_price': 6860.0,
#   'instrument_token': 'NSE_FO|38915'},
#  'NSE_FO:BANKNIFTY24NOV49100CE': {'last_price': 1489.6,
#   'instrument_token': 'NSE_FO|40937'},
#  'NSE_FO:BANKNIFTY24NOV56400CE': {'last_price': 3.95,
#   'instrument_token': 'NSE_FO|51841'},
#  'NSE_FO:BANKNIFTY24NOV53500PE': {'last_price': 3028.0,
#   'instrument_token': 'NSE_FO|43283'},
#  'NSE_FO:BANKNIFTY24NOV52100CE': {'last_price': 55.05,
#   'instrument_token': 'NSE_FO|41554'},
#  'NSE_FO:BANKNIFTY24NOV50500CE': {'last_price': 464.35,
#   'instrument_token': 'NSE_FO|41365'},
#  'NSE_FO:BANKNIFTY24NOV54700PE': {'last_price': 4172.9,
#   'instrument_token': 'NSE_FO|48329'},
#  'NSE_FO:BANKNIFTY24NOV55200CE': {'last_price': 5.55,
#   'instrument_token': 'NSE_FO|48481'},
#  'NSE_FO:BANKNIFTY24NOV59500CE': {'last_price': 4.95,
#   'instrument_token': 'NSE_FO|55588'},
#  'NSE_FO:BANKNIFTY24NOV50400PE': {'last_price': 452.0,
#   'instrument_token': 'NSE_FO|41353'},
#  'NSE_FO:BANKNIFTY24NOV54800CE': {'last_price': 5.2,
#   'instrument_token': 'NSE_FO|48334'},
#  'NSE_FO:BANKNIFTY24NOV55100PE': {'last_price': 2750.0,
#   'instrument_token': 'NSE_FO|48480'},
#  'NSE_FO:BANKNIFTY24NOV49700PE': {'last_price': 217.5,
#   'instrument_token': 'NSE_FO|41302'},
#  'NSE_FO:BANKNIFTY24NOV49800CE': {'last_price': 915.15,
#   'instrument_token': 'NSE_FO|41303'},
#  'NSE_FO:BANKNIFTY24NOV45500CE': {'last_price': 6300.0,
#   'instrument_token': 'NSE_FO|39111'},
#  'NSE_FO:BANKNIFTY24NOV49400CE': {'last_price': 1230.0,
#   'instrument_token': 'NSE_FO|41132'},
#  'NSE_FO:BANKNIFTY24NOV51600PE': {'last_price': 1230.35,
#   'instrument_token': 'NSE_FO|41516'},
#  'NSE_FO:BANKNIFTY24NOV50800PE': {'last_price': 660.9,
#   'instrument_token': 'NSE_FO|41424'},
#  'NSE_FO:BANKNIFTY24NOV48600CE': {'last_price': 1930.5,
#   'instrument_token': 'NSE_FO|40862'},
#  'NSE_FO:BANKNIFTY24NOV55900PE': {'last_price': 5192.05,
#   'instrument_token': 'NSE_FO|51831'},
#  'NSE_FO:BANKNIFTY24NOV53200CE': {'last_price': 12.45,
#   'instrument_token': 'NSE_FO|41676'},
#  'NSE_FO:BANKNIFTY24NOV43500PE': {'last_price': 2.3,
#   'instrument_token': 'NSE_FO|38805'},
#  'NSE_FO:BANKNIFTY24NOV57500CE': {'last_price': 3.4,
#   'instrument_token': 'NSE_FO|55148'},
#  'NSE_FO:BANKNIFTY24NOV60500CE': {'last_price': 3.05,
#   'instrument_token': 'NSE_FO|55602'},
#  'NSE_FO:BANKNIFTY24NOV54000PE': {'last_price': 3480.35,
#   'instrument_token': 'NSE_FO|46326'},
#  'NSE_FO:BANKNIFTY24NOV56700CE': {'last_price': 3.65,
#   'instrument_token': 'NSE_FO|51847'},
#  'NSE_FO:BANKNIFTY24NOV47800PE': {'last_price': 30.55,
#   'instrument_token': 'NSE_FO|39694'},
#  'NSE_FO:BANKNIFTY24NOV54100CE': {'last_price': 7.4,
#   'instrument_token': 'NSE_FO|46329'},
#  'NSE_FO:BANKNIFTY24NOV47900CE': {'last_price': 2569.95,
#   'instrument_token': 'NSE_FO|39695'},
#  'NSE_FO:BANKNIFTY24NOV52400CE': {'last_price': 37.95,
#   'instrument_token': 'NSE_FO|41600'},
#  'NSE_FO:BANKNIFTY24NOV52300PE': {'last_price': 1883.45,
#   'instrument_token': 'NSE_FO|41595'},
#  'NSE_FO:BANKNIFTY24NOV56600PE': {'last_price': 4323.65,
#   'instrument_token': 'NSE_FO|51846'},
#  'NSE_FO:BANKNIFTY24NOV49300PE': {'last_price': 142.0,
#   'instrument_token': 'NSE_FO|41130'},
#  'NSE_FO:BANKNIFTY24NOV52700PE': {'last_price': 2207.75,
#   'instrument_token': 'NSE_FO|41612'},
#  'NSE_FO:BANKNIFTY24NOV54400PE': {'last_price': 3927.7,
#   'instrument_token': 'NSE_FO|46663'},
#  'NSE_FO:BANKNIFTY24NOV47500CE': {'last_price': 3086.3,
#   'instrument_token': 'NSE_FO|39216'},
#  'NSE_FO:BANKNIFTY24NOV45000PE': {'last_price': 4.7,
#   'instrument_token': 'NSE_FO|39041'},
#  'NSE_FO:BANKNIFTY24NOV51900PE': {'last_price': 1496.3,
#   'instrument_token': 'NSE_FO|41546'},
#  'NSE_FO:BANKNIFTY24NOV53100PE': {'last_price': 2596.15,
#   'instrument_token': 'NSE_FO|41675'},
#  'NSE_FO:BANKNIFTY24NOV55600CE': {'last_price': 4.15,
#   'instrument_token': 'NSE_FO|51113'},
#  'NSE_FO:BANKNIFTY24NOV57400PE': {'last_price': 0.0,
#   'instrument_token': 'NSE_FO|55147'},
#  'NSE_FO:BANKNIFTY24NOV48900PE': {'last_price': 96.2,
#   'instrument_token': 'NSE_FO|40927'},
#  'NSE_FO:BANKNIFTY24NOV56000CE': {'last_price': 4.6,
#   'instrument_token': 'NSE_FO|51832'},
#  'NSE_FO:BANKNIFTY24NOV55500PE': {'last_price': 4516.35,
#   'instrument_token': 'NSE_FO|51112'},
#  'NSE_FO:BANKNIFTY24NOV51200PE': {'last_price': 916.15,
#   'instrument_token': 'NSE_FO|41469'},
#  'NSE_FO:BANKNIFTY24NOV51300CE': {'last_price': 166.95,
#   'instrument_token': 'NSE_FO|41493'},
#  'NSE_FO:BANKNIFTY24NOV53900CE': {'last_price': 7.25,
#   'instrument_token': 'NSE_FO|46323'},
#  'NSE_FO:BANKNIFTY24NOV50900CE': {'last_price': 289.95,
#   'instrument_token': 'NSE_FO|41441'},
#  'NSE_FO:BANKNIFTY24NOV53800PE': {'last_price': 3160.75,
#   'instrument_token': 'NSE_FO|46322'},
#  'NSE_FO:BANKNIFTY24NOV50300PE': {'last_price': 405.0,
#   'instrument_token': 'NSE_FO|41323'},
#  'NSE_FO:BANKNIFTY24NOV55300CE': {'last_price': 5.4,
#   'instrument_token': 'NSE_FO|48661'},
#  'NSE_FO:BANKNIFTY24NOV54600PE': {'last_price': 3690.0,
#   'instrument_token': 'NSE_FO|48323'},
#  'NSE_FO:BANKNIFTY24NOV51000CE': {'last_price': 254.0,
#   'instrument_token': 'NSE_FO|41451'},
#  'NSE_FO:BANKNIFTY24NOV49900CE': {'last_price': 845.3,
#   'instrument_token': 'NSE_FO|41310'},
#  'NSE_FO:BANKNIFTY24NOV58000PE': {'last_price': 7107.4,
#   'instrument_token': 'NSE_FO|55313'},
#  'NSE_FO:BANKNIFTY24NOV51900CE': {'last_price': 74.0,
#   'instrument_token': 'NSE_FO|41545'},
#  'NSE_FO:BANKNIFTY24NOV44000PE': {'last_price': 2.3,
#   'instrument_token': 'NSE_FO|38916'},
#  'NSE_FO:BANKNIFTY24NOV48000CE': {'last_price': 2490.95,
#   'instrument_token': 'NSE_FO|39697'},
#  'NSE_FO:BANKNIFTY24NOV48300PE': {'last_price': 51.0,
#   'instrument_token': 'NSE_FO|40476'},
#  'NSE_FO:BANKNIFTY24NOV52800PE': {'last_price': 2360.1,
#   'instrument_token': 'NSE_FO|41627'},
#  'NSE_FO:BANKNIFTY24NOV47400CE': {'last_price': 0.0,
#   'instrument_token': 'NSE_FO|39213'},
#  'NSE_FO:BANKNIFTY24NOV52900CE': {'last_price': 18.55,
#   'instrument_token': 'NSE_FO|41643'},
#  'NSE_FO:BANKNIFTY24NOV52000CE': {'last_price': 63.5,
#   'instrument_token': 'NSE_FO|41547'},
#  'NSE_FO:BANKNIFTY24NOV56300CE': {'last_price': 4.75,
#   'instrument_token': 'NSE_FO|51838'},
#  'NSE_FO:BANKNIFTY24NOV47300PE': {'last_price': 19.6,
#   'instrument_token': 'NSE_FO|39209'},
#  'NSE_FO:BANKNIFTY24NOV56200PE': {'last_price': 5512.35,
#   'instrument_token': 'NSE_FO|51837'},
#  'NSE_FO:BANKNIFTY24NOV43000PE': {'last_price': 2.0,
#   'instrument_token': 'NSE_FO|38675'},
#  'NSE_FO:BANKNIFTY24NOV59500PE': {'last_price': 7395.35,
#   'instrument_token': 'NSE_FO|55589'},
#  'NSE_FO:BANKNIFTY24NOV55200PE': {'last_price': 0.0,
#   'instrument_token': 'NSE_FO|48660'},
#  'NSE_FO:BANKNIFTY24NOV54700CE': {'last_price': 5.8,
#   'instrument_token': 'NSE_FO|48324'},
#  'NSE_FO:BANKNIFTY24NOV50400CE': {'last_price': 520.0,
#   'instrument_token': 'NSE_FO|41324'},
#  'NSE_FO:BANKNIFTY24NOV45500PE': {'last_price': 6.6,
#   'instrument_token': 'NSE_FO|39122'},
#  'NSE_FO:BANKNIFTY24NOV48400CE': {'last_price': 2300.0,
#   'instrument_token': 'NSE_FO|40479'},
#  'NSE_FO:BANKNIFTY24NOV49800PE': {'last_price': 240.0,
#   'instrument_token': 'NSE_FO|41305'},
#  'NSE_FO:BANKNIFTY24NOV53400PE': {'last_price': 2535.95,
#   'instrument_token': 'NSE_FO|42694'},
#  'NSE_FO:BANKNIFTY24NOV42500CE': {'last_price': 8475.0,
#   'instrument_token': 'NSE_FO|38526'},
#  'NSE_FO:BANKNIFTY24NOV49000CE': {'last_price': 1579.6,
#   'instrument_token': 'NSE_FO|40930'},
#  'NSE_FO:BANKNIFTY24NOV53500CE': {'last_price': 9.4,
#   'instrument_token': 'NSE_FO|43282'},
#  'NSE_FO:BANKNIFTY24NOV54100PE': {'last_price': 3708.1,
#   'instrument_token': 'NSE_FO|46641'},
#  'NSE_FO:BANKNIFTY24NOV56700PE': {'last_price': 0.0,
#   'instrument_token': 'NSE_FO|51848'},
#  'NSE_FO:BANKNIFTY24NOV47800CE': {'last_price': 3051.45,
#   'instrument_token': 'NSE_FO|39367'},
#  'NSE_FO:BANKNIFTY24NOV49500CE': {'last_price': 1135.85,
#   'instrument_token': 'NSE_FO|41287'},
#  'NSE_FO:BANKNIFTY24NOV52400PE': {'last_price': 1947.4,
#   'instrument_token': 'NSE_FO|41603'},
#  'NSE_FO:BANKNIFTY24NOV49400PE': {'last_price': 153.05,
#   'instrument_token': 'NSE_FO|41284'},
#  'NSE_FO:BANKNIFTY24NOV43500CE': {'last_price': 8220.0,
#   'instrument_token': 'NSE_FO|38747'},
#  'NSE_FO:BANKNIFTY24NOV51800PE': {'last_price': 1404.75,
#   'instrument_token': 'NSE_FO|41528'},
#  'NSE_FO:BANKNIFTY24NOV47700PE': {'last_price': 28.8,
#   'instrument_token': 'NSE_FO|39221'},
#  'NSE_FO:BANKNIFTY24NOV62000PE': {'last_price': 11900.0,
#   'instrument_token': 'NSE_FO|55609'},
#  'NSE_FO:BANKNIFTY24NOV58500CE': {'last_price': 3.75,
#   'instrument_token': 'NSE_FO|55564'},
#  'NSE_FO:BANKNIFTY24NOV54200CE': {'last_price': 6.3,
#   'instrument_token': 'NSE_FO|46642'},
#  'NSE_FO:BANKNIFTY24NOV58000CE': {'last_price': 3.5,
#   'instrument_token': 'NSE_FO|55312'},
#  'NSE_FO:BANKNIFTY24NOV53000PE': {'last_price': 2532.25,
#   'instrument_token': 'NSE_FO|41662'},
#  'NSE_FO:BANKNIFTY24NOV56800CE': {'last_price': 4.55,
#   'instrument_token': 'NSE_FO|51849'},
#  'NSE_FO:BANKNIFTY24NOV51300PE': {'last_price': 988.0,
#   'instrument_token': 'NSE_FO|41498'},
#  'NSE_FO:BANKNIFTY24NOV52500CE': {'last_price': 31.25,
#   'instrument_token': 'NSE_FO|41604'},
#  'NSE_FO:BANKNIFTY24NOV61000CE': {'last_price': 2.95,
#   'instrument_token': 'NSE_FO|55604'},
#  'NSE_FO:BANKNIFTY24NOV50800CE': {'last_price': 323.3,
#   'instrument_token': 'NSE_FO|41413'},
#  'NSE_FO:BANKNIFTY24NOV53900PE': {'last_price': 3278.3,
#   'instrument_token': 'NSE_FO|46324'},
#  'NSE_FO:BANKNIFTY24NOV48900CE': {'last_price': 1664.25,
#   'instrument_token': 'NSE_FO|40890'},
#  'NSE_FO:BANKNIFTY24NOV50700PE': {'last_price': 590.0,
#   'instrument_token': 'NSE_FO|41408'},
#  'NSE_FO:BANKNIFTY24NOV55600PE': {'last_price': 3870.05,
#   'instrument_token': 'NSE_FO|51114'},
#  'NSE_FO:BANKNIFTY24NOV55700CE': {'last_price': 4.8,
#   'instrument_token': 'NSE_FO|51115'},
#  'NSE_FO:BANKNIFTY24NOV51400CE': {'last_price': 148.2,
#   'instrument_token': 'NSE_FO|41505'},
#  'NSE_FO:BANKNIFTY24NOV48800PE': {'last_price': 86.0,
#   'instrument_token': 'NSE_FO|40885'},
#  'NSE_FO:BANKNIFTY24NOV53100CE': {'last_price': 14.85,
#   'instrument_token': 'NSE_FO|41669'},
#  'NSE_FO:BANKNIFTY24NOV57300PE': {'last_price': 4949.65,
#   'instrument_token': 'NSE_FO|55145'},
#  'NSE_FO:BANKNIFTY24NOV59000PE': {'last_price': 8400.0,
#   'instrument_token': 'NSE_FO|55575'},
#  'NSE_FO:BANKNIFTY24NOV57400CE': {'last_price': 3.6,
#   'instrument_token': 'NSE_FO|55146'},
#  'NSE_FO:BANKNIFTY24NOV44500PE': {'last_price': 2.85,
#   'instrument_token': 'NSE_FO|38964'}}

# %%
def find_option(optionChain,near_val):
	call_symbol = {}
	put_symbol = {}
	trade_symbol = {}
	for i in range(5):
		try:
			ltp_data = get_quotes(optionChain)['data']
		except:
			sleep(0.5)
			ltp_data = get_quotes(optionChain)['data']
		for k,v in ltp_data.items():
			# Call Symbol
			if float(v['last_price']) <= near_val and k[-2:] == 'CE':
				call_symbol.update({v['instrument_token']: float(v['last_price'])})
			# Put Symbol
			if float(v['last_price']) <= near_val and k[-2:] == 'PE':
				put_symbol.update({v['instrument_token']: float(v['last_price'])})
		if call_symbol and put_symbol:
			ce_val = min(list(call_symbol.values()), key=lambda x: abs(x-near_val))
			pe_val = min(list(put_symbol.values()), key=lambda x: abs(x-near_val))
			for a, b in call_symbol.items():
				if b == ce_val:
					trade_symbol.update({a: b})
			for c, d in put_symbol.items():
				if d == pe_val:
					trade_symbol.update({c: d})
		if trade_symbol:
			return trade_symbol
		else:
			sleep(1)
	return 'Symbol Not found'
trade_symbol = find_option(optionChain,500)
trade_symbol
# Out:
# {'NSE_FO|41365': 464.35, 'NSE_FO|41366': 489.4}

# %%
list(trade_symbol.keys())[0]
# Out:
# 'NSE_FO|41365'

# %%
instrument_key = list(trade_symbol.keys())[0]
instrument_name = next((k for k, v in ltp_data['data'].items() if v['instrument_token'] == instrument_key), None)
instrument_name
# Out:
# 'NSE_FO:BANKNIFTY24NOV50500CE'

# %%
instrument_key = list(trade_symbol.keys())[1]
instrument_name = next((k for k, v in ltp_data['data'].items() if v['instrument_token'] == instrument_key), None)
instrument_name
# Out:
# 'NSE_FO:BANKNIFTY24NOV50500PE'
